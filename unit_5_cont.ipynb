# %% [markdown]
# <a href="https://colab.research.google.com/github/NandanaNair05/python-codes/blob/main/unit_5_cont.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class NegativeNumberError(Exception):
    """Raised when a negative number is entered."""
    pass

def check_number(num):
    if num < 0:
        raise NegativeNumberError("Negative number not allowed!")
    else:
        print(f"Square of {num} is {num ** 2}")

try:
    n = int(input("Enter a positive number: "))
    check_number(n)
except NegativeNumberError as e:
    print("Custom Exception:", e)
except ValueError:
    print("Please enter a valid integer.")
# Out:
# Enter a positive number: 5
# Square of 5 is 25

# %%
class AgeTooSmallError(Exception):
    """Raised when age is less than 18"""
    pass

try:
    age = int(input("Enter your age: "))
    if age < 18:
        raise AgeTooSmallError("You must be at least 18 years old.")
    print("Access granted.")
except AgeTooSmallError as e:
    print("Custom Exception:", e)
except ValueError:
    print("Invalid input. Please enter a number.")
finally:
    print("Thank you for using our system.")
# Out:
# Enter your age: 12
# Custom Exception: You must be at least 18 years old.
# Thank you for using our system.
